# %%
import numpy as np
import pandas as pd


from plotly.offline import init_notebook_mode, iplot, plot
import plotly as py
init_notebook_mode(connected=True)
import plotly.graph_objs as go

from wordcloud import WordCloud
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
pd.set_option('display.max_rows', 50)

# %%
df_da_or = pd.read_csv('info_data_analyst_clean.csv')
df_ds_or = pd.read_csv('info_data_scientist_clean.csv')

# %%
df_da = df_da_or.copy()
df_ds = df_ds_or.copy()

# %%
df_da.drop(columns = 'Unnamed: 0', inplace=True)
df_ds.drop(columns = 'Unnamed: 0', inplace=True)

# %%
df_da.head(1)
# Out:
#   Nombre empresa      Puesto ofertado  Ubicación Días activos  Nº Solicitudes  \
# 0         Amazon  Junior Data Analyst  Barcelona      6 horas              66
#
#   Nivel experiencia                                             Sector  \
# 0   Sin experiencia  Software Servicios y tecnologías de la informa...
#
#        Tipo jornada                                Funciones laborales  \
# 0  Jornada completa  Estrategia/planificación Análisis Tecnología d...
#
#                                          Descripción
# 0  Description\n\nJunior Data Analyst\nWe are hir...

# %% [markdown]
# ### Concatenar los dos DF creando columna para agrupar por tipo.

# %%
df_da['Tipo puesto'] = pd.Series('')
df_ds['Tipo puesto'] = pd.Series('')

# %%
df_da['Tipo puesto'] = 'Data Analyst'
df_ds['Tipo puesto'] = 'Data Scientist'

# %%
df = pd.concat([df_da, df_ds])

# %%
df = df.reset_index()

# %%
df.drop(columns = 'index', inplace=True)

# %%
df
# Out:
#                            Nombre empresa  \
# 0                                  Amazon
# 1                            Packlink.com
# 2                         Mutua Madrileña
# 3                                Lookiero
# 4                                    YEGO
# ..                                    ...
# 995                        Page Personnel
# 996                        Siemens Gamesa
# 997       Barcelona Supercomputing Center
# 998                         Grupo Digital
# 999  Universitat Pompeu Fabra - Barcelona
#
#                                        Puesto ofertado   Ubicación  \
# 0                                  Junior Data Analyst   Barcelona
# 1                                Business Data Analyst      Madrid
# 2                                         Data Analyst      Madrid
# 3                                         Data Analyst  Respaldiza
# 4                                  Junior Data Analyst   Barcelona
# ..                                                 ...         ...
# 995  Java Developer - International Telecommunicati...   Barcelona
# 996       Data Engineer - Digital Ventures Lab (f/m/x)  Sarriguren
# 997                 Quantum algorithms researcher (R3)   Barcelona
# 998       Data Engineer / Data Integration PowerCenter   Barcelona
# 999  Data Analyst UPF-La Caixa - Full Time Research...   Barcelona
#
#     Días activos  Nº Solicitudes        Nivel experiencia  \
# 0        6 horas              66          Sin experiencia
# 1       1 semana             638               Intermedio
# 2      2 semanas            3490  Algo de responsabilidad
# 3      2 semanas            3374               Intermedio
# 4         3 días            1122          Sin experiencia
# ..           ...             ...                      ...
# 995      3 meses              23          Sin experiencia
# 996       3 días              49          Sin experiencia
# 997     1 semana              77  Algo de responsabilidad
# 998       3 días              33          Sin experiencia
# 999       2 días             406          Sin experiencia
#
#                                                 Sector      Tipo jornada  \
# 0    Software Servicios y tecnologías de la informa...  Jornada completa
# 1    Servicios y tecnologías de la información Logí...  Jornada completa
# 2                                              Seguros  Jornada completa
# 3                                        Sector textil  Jornada completa
# 4    Software Marketing y publicidad Transporte por...  Jornada completa
# ..                                                 ...               ...
# 995  Servicios y tecnologías de la información Dota...  Jornada completa
# 996  Construcción Dotación y selección de personal ...  Jornada completa
# 997  Servicios y tecnologías de la información Soft...  Jornada completa
# 998  Servicios y tecnologías de la información Soft...  Jornada completa
# 999     Enseñanza superior Investigación Biotecnología  Jornada completa
#
#                                    Funciones laborales  \
# 0    Estrategia/planificación Análisis Tecnología d...
# 1       Negocios Tecnología de la información Análisis
# 2                                                 Otro
# 3              Ingeniería Tecnología de la información
# 4       Ciencias Análisis Tecnología de la información
# ..                                                 ...
# 995            Ingeniería Tecnología de la información
# 996                       Tecnología de la información
# 997  Investigación Análisis Tecnología de la inform...
# 998                       Tecnología de la información
# 999                       Tecnología de la información
#
#                                            Descripción     Tipo puesto
# 0    Description\n\nJunior Data Analyst\nWe are hir...    Data Analyst
# 1    Do you want to be a part of a fast-paced compa...    Data Analyst
# 2    Anunciado por\nAdriana Sánchez\nExperta Desarr...    Data Analyst
# 3    Anunciado por\nElena Martín\nTalent Acquisitio...    Data Analyst
# 4    Mission\nAs a Junior Data Analyst you will sup...    Data Analyst
# ..                                                 ...             ...
# 995  Java Developer - International Telecommunicati...  Data Scientist
# 996  It takes the brightest minds to be a technolog...  Data Scientist
# 997  Context and Mission\n\nThe Quantic group is a ...  Data Scientist
# 998  Seleccionamos para importante compañia del sec...  Data Scientist
# 999  The Department of Economics and Business at Un...  Data Scientist
#
# [1000 rows x 11 columns]

# %% [markdown]
# ### Gráficos:

# %%
df[df['Tipo puesto']=='Data Scientist']
# Out:
#                            Nombre empresa  \
# 500                                Amazon
# 501          Zurich Insurance Company Ltd
# 502                       El Corte Inglés
# 503                                 WIRIS
# 504                                 MANGO
# ..                                    ...
# 995                        Page Personnel
# 996                        Siemens Gamesa
# 997       Barcelona Supercomputing Center
# 998                         Grupo Digital
# 999  Universitat Pompeu Fabra - Barcelona
#
#                                        Puesto ofertado     Ubicación  \
# 500                                     Data Scientist     Barcelona
# 501                                     Data Scientist     Barcelona
# 502                                      Data Engineer        Madrid
# 503                                      Data Engineer     Barcelona
# 504                                     Data Scientist  Palau-solità
# ..                                                 ...           ...
# 995  Java Developer - International Telecommunicati...     Barcelona
# 996       Data Engineer - Digital Ventures Lab (f/m/x)    Sarriguren
# 997                 Quantum algorithms researcher (R3)     Barcelona
# 998       Data Engineer / Data Integration PowerCenter     Barcelona
# 999  Data Analyst UPF-La Caixa - Full Time Research...     Barcelona
#
#     Días activos  Nº Solicitudes        Nivel experiencia  \
# 500       2 días             749                  no_data
# 501     11 horas             180               Intermedio
# 502     1 semana            2011  Algo de responsabilidad
# 503     1 semana             305  Algo de responsabilidad
# 504      7 horas             215  Algo de responsabilidad
# ..           ...             ...                      ...
# 995      3 meses              23          Sin experiencia
# 996       3 días              49          Sin experiencia
# 997     1 semana              77  Algo de responsabilidad
# 998       3 días              33          Sin experiencia
# 999       2 días             406          Sin experiencia
#
#                                                 Sector      Tipo jornada  \
# 500  Software Servicios y tecnologías de la informa...  Jornada completa
# 501                      Seguros Servicios financieros  Jornada completa
# 502  Venta al por menor Artículos de consumo Servic...  Jornada completa
# 503                                           Software  Jornada completa
# 504                                 Venta al por menor  Jornada completa
# ..                                                 ...               ...
# 995  Servicios y tecnologías de la información Dota...  Jornada completa
# 996  Construcción Dotación y selección de personal ...  Jornada completa
# 997  Servicios y tecnologías de la información Soft...  Jornada completa
# 998  Servicios y tecnologías de la información Soft...  Jornada completa
# 999     Enseñanza superior Investigación Biotecnología  Jornada completa
#
#                                    Funciones laborales  \
# 500            Ingeniería Tecnología de la información
# 501                           Estrategia/planificación
# 502  Consultoría Ingeniería Tecnología de la inform...
# 503                       Tecnología de la información
# 504     Análisis Negocios Tecnología de la información
# ..                                                 ...
# 995            Ingeniería Tecnología de la información
# 996                       Tecnología de la información
# 997  Investigación Análisis Tecnología de la inform...
# 998                       Tecnología de la información
# 999                       Tecnología de la información
#
#                                            Descripción     Tipo puesto
# 500  Description\n\nWe are looking for a Data Scien...  Data Scientist
# 501  The purpose of Zurich is...\n\nWhat are we loo...  Data Scientist
# 502  Si lo que buscas es una empresa innovadora y l...  Data Scientist
# 503  Anunciado por\nJulia Abad Castelló\nTalent Acq...  Data Scientist
# 504  Buscamos un/a Data Scientist para que se incor...  Data Scientist
# ..                                                 ...             ...
# 995  Java Developer - International Telecommunicati...  Data Scientist
# 996  It takes the brightest minds to be a technolog...  Data Scientist
# 997  Context and Mission\n\nThe Quantic group is a ...  Data Scientist
# 998  Seleccionamos para importante compañia del sec...  Data Scientist
# 999  The Department of Economics and Business at Un...  Data Scientist
#
# [500 rows x 11 columns]
