# %% [markdown]
# # Web scraping Linkedin
# ## DS Market research

# %% [markdown]
# ### Importar Pandas y activar el Chrome Driver

# %%
import pandas as pd

from selenium import webdriver

from selenium.webdriver.common.keys import Keys

from selenium.webdriver.common.action_chains import ActionChains

import time

# %%
chrome_driver = '/Users/cris/Documents/Repositorios/local_docs/chromedriver'

options = webdriver.ChromeOptions() # Añadimos un dic con todas las opciones de configuración de Chrome.

# options.add_argument('headless')

# Headless hace que el web scrapping vaya viendo lo que hace o no.

# Podemos configurar diversas opciones en líneas sucesivas.

driver = webdriver.Chrome(executable_path = chrome_driver, options = options)

# %%
def login(username, password):
    driver.get('https://www.linkedin.com/uas/login')

    username_input = driver.find_element_by_id('username')
    username_input.send_keys(username)

    password_input = driver.find_element_by_id('password')
    password_input.send_keys(password)
    password_input.submit()

# %%
username = 'c.espanaces@gmail.com'
password = 'aay}1\jsL<}L9qy;w}br'

login(username, password)

# %% [markdown]
# #### Iniciar búsqueda

# %%
search_job = driver.find_elements_by_tag_name('input')

# %%
search_job[1].send_keys('Data analyst')

# %%
search_job[1].send_keys(Keys.ENTER)

# %% [markdown]
# #### Pinchar en empleo:

# %%
driver.back()

# %%
b_jobs = driver.find_elements_by_tag_name('button')

# %%
b_jobs[8].click()

# %% [markdown]
# #### Recoger info puesto trabajo:

# %%
driver.back()

# %%
content = driver.find_elements_by_tag_name('div.flex-grow-1.artdeco-entity-lockup__content.ember-view')

# %%
lista_content = []

for i in content:
    lista_content.append(i.find_element_by_tag_name('a').get_attribute('href'))

# %% [markdown]
# ## Método 1

# %% [markdown]
# #### Buscar información dentro de cada página

# %%
# Creo lista con todos la información recopilada de la empresa, por orden.

def info_collect1(driver):

    info_df = []

    title = driver.find_elements_by_tag_name('div.jobs-details-top-card__content-container')

    title = title[0].text.splitlines()
    
    if len(title) < 9:
        info_df = []
        
        title = driver.find_elements_by_tag_name('div.jobs-details-top-card__content-container')

        title = title[0].text.splitlines()
    
    elif title[5] == 'Nuevo':
        title = [title[2], title[0], title[4], title[7], title[9]]
    
    else:
        title = [title[2], title[0], title[4], title[6], title[8]]
        
    
    info_job_comp = driver.find_elements_by_tag_name('li.artdeco-list__item.jobs-details-job-summary-list__item.jobs-details-job-summary-list__item--bullet')
    
    info_job_comp = info_job_comp[0].text.splitlines()
    
    
    job_desc = driver.find_elements_by_tag_name('div.jobs-box__html-content.jobs-description-content__text.t-14.t-normal')
    
    job_desc1 = job_desc[0].text.splitlines()[:-8]    
    
    tuple(job_desc)
    
    job_desc2 = job_desc[0].text.splitlines()[-8:]
    
    job_desc2 = [job_desc2[1], job_desc2[3], job_desc2[5], job_desc2[7]]
    
    info_df = title + job_desc2
    
    return info_df

# %%
# Creo los títulos de las columnas del df.

titulos_col = ['Nombre empresa', 'Puesto ofertado', 'Ubicación', 'Días activos', 'Nº Visualizaciones', 'Nivel experiencia', 'Sector', 'Tipo jornada', 'Funciones laborales']

# %%
jobs_list1 = pd.DataFrame()

# %%
for i in range(len(lista_content)):
    content[i].click()
    info_df = info_collect1(driver)
    df_prueba1 = pd.DataFrame([info_df], columns = titulos_col)
    jobs_list1 = jobs_list1.append(df_prueba1)

# %% [markdown]
# ## Método 2

# %%
# Creo lista con todos la información recopilada de la empresa, por orden.

def info_collect2(driver):

    info_df = []
    
    time.sleep(1)
    
    try:
        boton1 = driver.find_element_by_id('ember106')
        boton1.click()
    except:
        None
    
    try:
        empresa = driver.find_element_by_tag_name('a.ember-view.t-black.t-normal').text
    except:
        empresa = driver.find_element_by_tag_name('span.jobs-unified-top-card__subtitle-primary-grouping.mr2.t-black').text
    
    puesto = driver.find_element_by_tag_name('h1.t-24.t-bold').text
    ubicacion = driver.find_element_by_tag_name('span.jobs-unified-top-card__bullet').text
    tiempo_puesto = driver.find_element_by_tag_name('span.jobs-unified-top-card__posted-date').text
    
    try:
        solicitud = driver.find_element_by_tag_name('span.jobs-unified-top-card__applicant-count').text
    except:
        solicitud = ''
    
    info_pr = [empresa, puesto, ubicacion, tiempo_puesto, solicitud]
    
    try:
        boton2 = driver.find_element_by_id('ember60')
        boton2.click()
    except:
        None
    
    try:
        info_job_comp = driver.find_element_by_class_name('jobs-description-details').text
        info_job_comp = info_job_comp.splitlines()
        if info_job_comp[1]=='Nivel de experiencia':
            info_job_comp = [info_job_comp[2], info_job_comp[4], info_job_comp[6], info_job_comp[8]]
        
        elif info_job_comp[0]=='Nivel de experiencia':
            info_job_comp = [info_job_comp[1], info_job_comp[3], info_job_comp[5], info_job_comp[7]]
        
        else:
            info_job_comp = ['', info_job_comp[3], info_job_comp[5], info_job_comp[7]]
            
    except:
        info_job_comp = driver.find_element_by_class_name('jobs-description-details').text
        info_job_comp = info_job_comp.splitlines()
        info_job_comp = [info_job_comp[1], info_job_comp[3], '', '']
    
    description = driver.find_elements_by_tag_name('div.jobs-box__html-content.jobs-description-content__text.t-14.t-normal')
    description = description[0].text
    
    info_df = info_pr + info_job_comp

    return info_df

# %%
# Creo los títulos de las columnas del df.

titulos_col = ['Nombre empresa', 'Puesto ofertado', 'Ubicación', 'Días activos', 'Nº Solicitudes', 'Nivel experiencia', 'Sector', 'Tipo jornada', 'Funciones laborales']

# %%
jobs_list = pd.DataFrame()

# %%
def contenido(driver):
    parentElement = driver.find_element_by_class_name("jobs-search-results__list.list-style-none")

    elementList = parentElement.find_elements_by_class_name("mr1.artdeco-entity-lockup__image.artdeco-entity-lockup__image--type-square.ember-view")

    x = []
    for i in elementList:
        x.append(i.find_element_by_tag_name('a').get_attribute('href'))
    
    return x

# %%
for i in contenido(driver):
    driver.execute_script("window.open('');")
    driver.switch_to.window(driver.window_handles[-1])
    driver.get(i)
    info_df = info_collect2(driver)
    df_prueba1 = pd.DataFrame([info_df], columns = titulos_col)
    jobs_list = jobs_list.append(df_prueba1)
    driver.close()
    driver.switch_to.window(driver.window_handles[-1])

# %%
driver.find_element_by_class_name('jobs-description-details').text

# %%
jobs_list

# %%
driver.execute_script("window.open('');")
driver.switch_to.window(driver.window_handles[-1])
driver.get(lista_content[20])

# %%
driver.switch_to.window(driver.window_handles[-1])

# %%
driver.close()

# %%
jobs_list

# %%
parentElement = driver.find_element_by_class_name("jobs-search-results__list.list-style-none")

# %%
def contenido(driver):
    parentElement = driver.find_element_by_class_name("jobs-search-results__list.list-style-none")

    elementList = parentElement.find_elements_by_class_name("mr1.artdeco-entity-lockup__image.artdeco-entity-lockup__image--type-square.ember-view")

    x = []
    for i in elementList:
        x.append(i.find_element_by_tag_name('a').get_attribute('href'))
    
    return x

# %%
x = []
for i in elementList:
    x.append(i.find_element_by_tag_name('a').get_attribute('href'))

# %%
len

# %%
len(x)

# %%
count = 1
number = driver.find_elements_by_tag_name('li.artdeco-pagination__indicator.artdeco-pagination__indicator--number.ember-view')
count += 1

# %%
for i in number:
    print(i.text)

# %% [markdown]
# ## Método 3

# %%
parentElement = driver.find_element_by_class_name("jobs-search-results__list.list-style-none")

elementList = parentElement.find_elements_by_class_name("mr1.artdeco-entity-lockup__image.artdeco-entity-lockup__image--type-square.ember-view")

x = []
for i in elementList:
    x.append(i.find_element_by_tag_name('a').get_attribute('href'))

# %%
# Creo lista con todos la información recopilada de la empresa, por orden.

def info_collect(driver):

    info_df = []
    
    title = driver.find_elements_by_tag_name('div.jobs-details-top-card__content-container')
   
    title = title[0].text.splitlines()
    
    
    if len(title) < 9:

        title = [title [0], '', '', '', '']

    elif title[5] == 'Nuevo':
        title = [title[2], title[0], title[4], title[7], title[9]]

    else:
        title = [title[2], title[0], title[4], title[6], title[8]]
        
        
    
    info_job_comp = driver.find_elements_by_tag_name('li.artdeco-list__item.jobs-details-job-summary-list__item.jobs-details-job-summary-list__item--bullet')
    
    info_job_comp = info_job_comp[0].text.splitlines()
    
    
    job_desc = driver.find_elements_by_tag_name('div.jobs-box__html-content.jobs-description-content__text.t-14.t-normal')
    
    job_desc1 = job_desc[0].text.splitlines()[:-8]    
    
    tuple(job_desc)
    
    job_desc2 = job_desc[0].text.splitlines()[-8:]
    
    job_desc2 = [job_desc2[1], job_desc2[3], job_desc2[5], job_desc2[7]]
    
    info_df = title + job_desc2
    
    return info_df

# %%
def charge_web(driver):
    parentElement = driver.find_element_by_class_name("jobs-search-results__list.list-style-none")
    elementList = parentElement.find_elements_by_class_name("mr1.artdeco-entity-lockup__image.artdeco-entity-lockup__image--type-square.ember-view")

    for i in range(len(elementList)):    
        elementList[i].click()
        time.sleep(1)
        parentElement = driver.find_element_by_class_name("jobs-search-results__list.list-style-none")
        elementList = parentElement.find_elements_by_class_name("mr1.artdeco-entity-lockup__image.artdeco-entity-lockup__image--type-square.ember-view")
    
    return elementList

# %%
# Creo los títulos de las columnas del df.

titulos_col = ['Nombre empresa', 'Puesto ofertado', 'Ubicación', 'Días activos', 'Nº Solicitudes', 'Nivel experiencia', 'Sector', 'Tipo jornada', 'Funciones laborales']

# %%
jobs_list = pd.DataFrame()

# %%
def change_page(driver, count):
    number = driver.find_elements_by_tag_name('li.artdeco-pagination__indicator.artdeco-pagination__indicator--number.ember-view')

    lista_str = []
    lista_num = []

    for i in range(1, 34):
        lista_str.append(str(i))
        lista_num.append(i)

    for i in lista_num:

        if number[i].text == lista_str[i]:
            number[i].click()
            
    else:
        break

# %%
count = 1
while count < 2:
    elementList = charge_web(driver)
    
    for i in range(len(elementList)):
        elementList[i].click()
        time.sleep(1)
        info_df = info_collect(driver)
        df_prueba = pd.DataFrame([info_df], columns = titulos_col)
        jobs_list = jobs_list.append(df_prueba)
        time.sleep(5)

# %%
number = driver.find_elements_by_tag_name('li.artdeco-pagination__indicator.artdeco-pagination__indicator--number.ember-view')

lista_str = []
lista_num = []

for i in range(1, 34):
    lista_str.append(str(i))
    lista_num.append(i)

for i in lista_num:

    if number[i].text == lista_str[i]:
        number[i].click()

# %%
parentElement = driver.find_element_by_class_name("jobs-search-results__list.list-style-none")
elementList = parentElement.find_elements_by_class_name("mr1.artdeco-entity-lockup__image.artdeco-entity-lockup__image--type-square.ember-view")

for i in range(len(elementList)):    
    elementList[i].click()
    time.sleep(1)
    parentElement = driver.find_element_by_class_name("jobs-search-results__list.list-style-none")
    elementList = parentElement.find_elements_by_clas

# %% [markdown]
# ## Método 4

# %%
# Creo lista con todos la información recopilada de la empresa, por orden.

def info_collect(driver):

    info_df = []
    
    title = driver.find_elements_by_tag_name('div.jobs-details-top-card__content-container')
   
    title = title[0].text.splitlines()
    
    
    if len(title) < 9:

        title = [title [0], '', '', '', '']

    elif title[5] == 'Nuevo':
        title = [title[2], title[0], title[4], title[7], title[9]]

    else:
        title = [title[2], title[0], title[4], title[6], title[8]]
        
        
    
    info_job_comp = driver.find_elements_by_tag_name('li.artdeco-list__item.jobs-details-job-summary-list__item.jobs-details-job-summary-list__item--bullet')
    
    info_job_comp = info_job_comp[0].text.splitlines()
    
    
    job_desc = driver.find_elements_by_tag_name('div.jobs-box__html-content.jobs-description-content__text.t-14.t-normal')
    
    job_desc1 = [job_desc[0].text]
    

    
    job_desc2 = job_desc[0].text.splitlines()[-8:]
    
    job_desc2 = [job_desc2[1], job_desc2[3], job_desc2[5], job_desc2[7]]
    
    info_df = title + job_desc2 + job_desc1
    
    return info_df

# %%
# Creo los títulos de las columnas del df.

titulos_col = ['Nombre empresa', 'Puesto ofertado', 'Ubicación', 'Días activos', 'Nº Solicitudes', 'Nivel experiencia', 'Sector', 'Tipo jornada', 'Funciones laborales', 'Descripción']

# %%
jobs_list = pd.DataFrame()

# %%
parentElement = driver.find_element_by_class_name("jobs-search-results__list.list-style-none")
elementList = parentElement.find_elements_by_class_name("mr1.artdeco-entity-lockup__image.artdeco-entity-lockup__image--type-square.ember-view")

# %%
for i in range(len(elementList)):
    elementList[i].click()
    time.sleep(2)
    info_df = info_collect(driver)
    df_prueba = pd.DataFrame([info_df], columns = titulos_col)
    jobs_list = jobs_list.append(df_prueba)

# %%
jobs_list
# Out:
#                             Nombre empresa  \
# 0                                   Amazon
# 0                             Packlink.com
# 0                          Mutua Madrileña
# 0                                 Lookiero
# 0                                     YEGO
# ..                                     ...
# 0   Toronto Catholic District School Board
# 0   Toronto Catholic District School Board
# 0                                   Solera
# 0                                   Amazon
# 0                          Teleperformance
#
#                                  Puesto ofertado  \
# 0                            Junior Data Analyst
# 0                          Business Data Analyst
# 0                                   Data Analyst
# 0                                   Data Analyst
# 0                            Junior Data Analyst
# ..                                           ...
# 0                        Senior Database Analyst
# 0                        Senior Database Analyst
# 0                            FP&A Senior Analyst
# 0   HR Program Manager – Analytics and Reporting
# 0                   German Sales Quality Analyst
#
#                                             Ubicación  \
# 0                         Barcelona, Cataluña, España
# 0                 Madrid, Comunidad de Madrid, España
# 0                 Madrid, Comunidad de Madrid, España
# 0            Respaldiza, País Vasco / Euskadi, España
# 0                         Barcelona, Cataluña, España
# ..                                                ...
# 0   Valencia/València, Comunidad Valenciana / Comu...
# 0                          Tomares, Andalucía, España
# 0                         Comunidad de Madrid, España
# 0                       Córdoba y alrededores, España
# 0                         Barcelona, Cataluña, España
#
#                      Días activos        Nº Solicitudes  \
# 0     Publicado hace hace 6 horas    66 visualizaciones
# 0    Publicado hace hace 1 semana   638 visualizaciones
# 0   Publicado hace hace 2 semanas  3490 visualizaciones
# 0   Publicado hace hace 2 semanas  3374 visualizaciones
# 0      Publicado hace hace 3 días  1122 visualizaciones
# ..                            ...                   ...
# 0       Publicado hace hace 1 mes    17 visualizaciones
# 0       Publicado hace hace 1 mes    21 visualizaciones
# 0   Publicado hace hace 3 semanas    34 visualizaciones
# 0      Publicado hace hace 6 días    17 visualizaciones
# 0   Publicado hace hace 4 semanas    42 visualizaciones
#
#           Nivel experiencia  \
# 0           Sin experiencia
# 0                Intermedio
# 0   Algo de responsabilidad
# 0                Intermedio
# 0           Sin experiencia
# ..                      ...
# 0   Algo de responsabilidad
# 0   Algo de responsabilidad
# 0   Algo de responsabilidad
# 0                Intermedio
# 0   Algo de responsabilidad
#
#                                                Sector      Tipo jornada  \
# 0   Software Servicios y tecnologías de la informa...  Jornada completa
# 0   Servicios y tecnologías de la información Logí...  Jornada completa
# 0                                             Seguros  Jornada completa
# 0                                       Sector textil  Jornada completa
# 0   Software Marketing y publicidad Transporte por...  Jornada completa
# ..                                                ...               ...
# 0   Servicios y tecnologías de la información Soft...  Jornada completa
# 0   Servicios y tecnologías de la información Soft...  Jornada completa
# 0   Servicios y tecnologías de la información Soft...  Jornada completa
# 0   Servicios y tecnologías de la información Soft...  Jornada completa
# 0      Recursos humanos Seguros Servicios financieros  Jornada completa
#
#                                   Funciones laborales  \
# 0   Estrategia/planificación Análisis Tecnología d...
# 0      Negocios Tecnología de la información Análisis
# 0                                                Otro
# 0             Ingeniería Tecnología de la información
# 0      Ciencias Análisis Tecnología de la información
# ..                                                ...
# 0                        Tecnología de la información
# 0                        Tecnología de la información
# 0                                     Finanzas Ventas
# 0   Gestión de proyectos Tecnología de la información
# 0                                  Control de calidad
#
#                                           Descripción
# 0   Description\n\nJunior Data Analyst\nWe are hir...
# 0   Do you want to be a part of a fast-paced compa...
# 0   Anunciado por\nAdriana Sánchez\nExperta Desarr...
# 0   Anunciado por\nElena Martín\nTalent Acquisitio...
# 0   Mission\nAs a Junior Data Analyst you will sup...
# ..                                                ...
# 0   APPLICATIONS ARE INVITED FOR THE POSITION OF S...
# 0   APPLICATIONS ARE INVITED FOR THE POSITION OF S...
# 0   Who We Are\n\nSolera is a global leader in dat...
# 0   EU COUNTRY LOCATION FLEXIBLE***Amazon is a com...
# 0   Description\n\nWe are glad to invite you to jo...
#
# [814 rows x 10 columns]

# %%
jobs_list.to_csv(r'/Users/cris/Documents/Repositorios/EDA_DS_Market/info_data_analysis.csv', index = False)

# %%
jobs_list
# Out:
#                             Nombre empresa  \
# 0                                   Amazon
# 0                             Packlink.com
# 0                          Mutua Madrileña
# 0                                 Lookiero
# 0                                     YEGO
# ..                                     ...
# 0   Toronto Catholic District School Board
# 0   Toronto Catholic District School Board
# 0                                   Solera
# 0                                   Amazon
# 0                          Teleperformance
#
#                                  Puesto ofertado  \
# 0                            Junior Data Analyst
# 0                          Business Data Analyst
# 0                                   Data Analyst
# 0                                   Data Analyst
# 0                            Junior Data Analyst
# ..                                           ...
# 0                        Senior Database Analyst
# 0                        Senior Database Analyst
# 0                            FP&A Senior Analyst
# 0   HR Program Manager – Analytics and Reporting
# 0                   German Sales Quality Analyst
#
#                                             Ubicación  \
# 0                         Barcelona, Cataluña, España
# 0                 Madrid, Comunidad de Madrid, España
# 0                 Madrid, Comunidad de Madrid, España
# 0            Respaldiza, País Vasco / Euskadi, España
# 0                         Barcelona, Cataluña, España
# ..                                                ...
# 0   Valencia/València, Comunidad Valenciana / Comu...
# 0                          Tomares, Andalucía, España
# 0                         Comunidad de Madrid, España
# 0                       Córdoba y alrededores, España
# 0                         Barcelona, Cataluña, España
#
#                      Días activos        Nº Solicitudes  \
# 0     Publicado hace hace 6 horas    66 visualizaciones
# 0    Publicado hace hace 1 semana   638 visualizaciones
# 0   Publicado hace hace 2 semanas  3490 visualizaciones
# 0   Publicado hace hace 2 semanas  3374 visualizaciones
# 0      Publicado hace hace 3 días  1122 visualizaciones
# ..                            ...                   ...
# 0       Publicado hace hace 1 mes    17 visualizaciones
# 0       Publicado hace hace 1 mes    21 visualizaciones
# 0   Publicado hace hace 3 semanas    34 visualizaciones
# 0      Publicado hace hace 6 días    17 visualizaciones
# 0   Publicado hace hace 4 semanas    42 visualizaciones
#
#           Nivel experiencia  \
# 0           Sin experiencia
# 0                Intermedio
# 0   Algo de responsabilidad
# 0                Intermedio
# 0           Sin experiencia
# ..                      ...
# 0   Algo de responsabilidad
# 0   Algo de responsabilidad
# 0   Algo de responsabilidad
# 0                Intermedio
# 0   Algo de responsabilidad
#
#                                                Sector      Tipo jornada  \
# 0   Software Servicios y tecnologías de la informa...  Jornada completa
# 0   Servicios y tecnologías de la información Logí...  Jornada completa
# 0                                             Seguros  Jornada completa
# 0                                       Sector textil  Jornada completa
# 0   Software Marketing y publicidad Transporte por...  Jornada completa
# ..                                                ...               ...
# 0   Servicios y tecnologías de la información Soft...  Jornada completa
# 0   Servicios y tecnologías de la información Soft...  Jornada completa
# 0   Servicios y tecnologías de la información Soft...  Jornada completa
# 0   Servicios y tecnologías de la información Soft...  Jornada completa
# 0      Recursos humanos Seguros Servicios financieros  Jornada completa
#
#                                   Funciones laborales  \
# 0   Estrategia/planificación Análisis Tecnología d...
# 0      Negocios Tecnología de la información Análisis
# 0                                                Otro
# 0             Ingeniería Tecnología de la información
# 0      Ciencias Análisis Tecnología de la información
# ..                                                ...
# 0                        Tecnología de la información
# 0                        Tecnología de la información
# 0                                     Finanzas Ventas
# 0   Gestión de proyectos Tecnología de la información
# 0                                  Control de calidad
#
#                                           Descripción
# 0   Description\n\nJunior Data Analyst\nWe are hir...
# 0   Do you want to be a part of a fast-paced compa...
# 0   Anunciado por\nAdriana Sánchez\nExperta Desarr...
# 0   Anunciado por\nElena Martín\nTalent Acquisitio...
# 0   Mission\nAs a Junior Data Analyst you will sup...
# ..                                                ...
# 0   APPLICATIONS ARE INVITED FOR THE POSITION OF S...
# 0   APPLICATIONS ARE INVITED FOR THE POSITION OF S...
# 0   Who We Are\n\nSolera is a global leader in dat...
# 0   EU COUNTRY LOCATION FLEXIBLE***Amazon is a com...
# 0   Description\n\nWe are glad to invite you to jo...
#
# [814 rows x 10 columns]

# %% [markdown]
# ## Método DATA SCIENTIST

# %%
parentElement = driver.find_element_by_class_name("jobs-search-results__list.list-style-none")
elementList = parentElement.find_elements_by_class_name("mr1.artdeco-entity-lockup__image.artdeco-entity-lockup__image--type-square.ember-view")

# %%
# Creo los títulos de las columnas del df.

titulos_col = ['Nombre empresa', 'Puesto ofertado', 'Ubicación', 'Días activos', 'Nº Solicitudes', 'Nivel experiencia', 'Sector', 'Tipo jornada', 'Funciones laborales', 'Descripción']

# %%
jobs_data_scientist_list = pd.DataFrame()

# %%
for i in range(len(elementList)):
    elementList[i].click()
    time.sleep(2)
    info_df = info_collect(driver)
    df_prueba = pd.DataFrame([info_df], columns = titulos_col)
    jobs_data_scientist_list = jobs_data_scientist_list.append(df_prueba)

# %%
jobs_data_scientist_list
# Out:
#                                Nombre empresa  \
# 0                                      Amazon
# 0                Zurich Insurance Company Ltd
# 0                             El Corte Inglés
# 0                                       WIRIS
# 0                                       MANGO
# ..                                        ...
# 0   Eurecat - Centro Tecnológico de Catalunya
# 0             Barcelona Supercomputing Center
# 0                                      Amazon
# 0        Universitat Pompeu Fabra - Barcelona
# 0                               Grupo Digital
#
#                                       Puesto ofertado  \
# 0                                      Data Scientist
# 0                                      Data Scientist
# 0                                       Data Engineer
# 0                                       Data Engineer
# 0                                      Data Scientist
# ..                                                ...
# 0   ROBOTICS RESEARCHER (COMPUTER VISION AND DEEP ...
# 0                  Quantum algorithms researcher (R3)
# 0                                      Data Scientist
# 0                 MetaWireless Early-Stage Researcher
# 0       Data Engineer // Data Integration POWERCENTER
#
#                                      Ubicación                  Días activos  \
# 0                  Barcelona, Cataluña, España    Publicado hace hace 2 días
# 0                  Barcelona, Cataluña, España  Publicado hace hace 11 horas
# 0          Madrid, Comunidad de Madrid, España  Publicado hace hace 1 semana
# 0                      Barcelona y alrededores  Publicado hace hace 1 semana
# 0   Palau-solità i Plegamans, Cataluña, España   Publicado hace hace 7 horas
# ..                                         ...                           ...
# 0      Cerdanyola del Vallès, Cataluña, España  Publicado hace hace 15 horas
# 0                  Barcelona, Cataluña, España  Publicado hace hace 1 semana
# 0                  Barcelona, Cataluña, España     Publicado hace hace 1 día
# 0                  Barcelona, Cataluña, España     Publicado hace hace 1 mes
# 0                  Barcelona, Cataluña, España    Publicado hace hace 3 días
#
#           Nº Solicitudes        Nivel experiencia  \
# 0    749 visualizaciones         Job ID: A1469178
# 0    180 visualizaciones               Intermedio
# 0   2011 visualizaciones  Algo de responsabilidad
# 0    305 visualizaciones  Algo de responsabilidad
# 0    215 visualizaciones  Algo de responsabilidad
# ..                   ...                      ...
# 0     24 visualizaciones          Sin experiencia
# 0     53 visualizaciones  Algo de responsabilidad
# 0     90 visualizaciones          Sin experiencia
# 0     12 visualizaciones  Algo de responsabilidad
# 0     23 visualizaciones          Sin experiencia
#
#                                                Sector       Tipo jornada  \
# 0   Software Servicios y tecnologías de la informa...   Jornada completa
# 0                       Seguros Servicios financieros   Jornada completa
# 0   Venta al por menor Artículos de consumo Servic...   Jornada completa
# 0                                            Software   Jornada completa
# 0                                  Venta al por menor   Jornada completa
# ..                                                ...                ...
# 0   Servicios y tecnologías de la información Soft...  Contrato por obra
# 0   Servicios y tecnologías de la información Soft...   Jornada completa
# 0   Servicios y tecnologías de la información Soft...   Jornada completa
# 0           Enseñanza superior Software Investigación   Jornada completa
# 0                                            Internet   Jornada completa
#
#                                   Funciones laborales  \
# 0             Ingeniería Tecnología de la información
# 0                            Estrategia/planificación
# 0   Consultoría Ingeniería Tecnología de la inform...
# 0                        Tecnología de la información
# 0      Análisis Negocios Tecnología de la información
# ..                                                ...
# 0                                                Otro
# 0   Investigación Análisis Tecnología de la inform...
# 0             Ingeniería Tecnología de la información
# 0   Investigación Análisis Tecnología de la inform...
# 0                        Tecnología de la información
#
#                                           Descripción
# 0   Description\n\nWe are looking for a Data Scien...
# 0   The purpose of Zurich is...\n\nWhat are we loo...
# 0   Si lo que buscas es una empresa innovadora y l...
# 0   Anunciado por\nJulia Abad Castelló\nTalent Acq...
# 0   Buscamos un/a Data Scientist para que se incor...
# ..                                                ...
# 0   Eurecat Centro Tecnológico de Cataluña\n\nCATA...
# 0   Offer Description\n\nContext and Mission\n\nTh...
# 0   We are looking for a Data Scientist to help Am...
# 0   The Wireless & Secure Communications (WiSeCom)...
# 0   Seleccionamos para importante compañia del sec...
#
# [515 rows x 10 columns]

# %%
jobs_data_scientist_list.to_csv('info_data_scientist.csv')
