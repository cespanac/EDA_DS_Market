# %% [markdown]
# # Web scraping Linkedin
# ## DS Market research

# %% [markdown]
# ### Importar Pandas y activar el Chrome Driver

# %%
import pandas as pd

from selenium import webdriver

from selenium.webdriver.common.keys import Keys

from selenium.webdriver.common.action_chains import ActionChains

import time

# %%
chrome_driver = '/Users/cris/Repositorios/local_docs/curso_ds21/chromedriver'

options = webdriver.ChromeOptions() # Añadimos un dic con todas las opciones de configuración de Chrome.

# options.add_argument('headless')

# Headless hace que el web scrapping vaya viendo lo que hace o no.

# Podemos configurar diversas opciones en líneas sucesivas.

driver = webdriver.Chrome(executable_path = chrome_driver, options = options)

# %% [markdown]
# ## Abrir Linkedin y loggearse

# %%
def login(username, password):
    driver.get('https://www.linkedin.com/uas/login')

    username_input = driver.find_element_by_id('username')
    username_input.send_keys(username)

    password_input = driver.find_element_by_id('password')
    password_input.send_keys(password)
    password_input.submit()

# %%
username = 'john_ds99@outlook.com'
password = 'vUgrH8D6lCKY6XasC6dZ'

login(username, password)

# %% [markdown]
# #### Iniciar búsqueda

# %%
search_job = driver.find_element_by_tag_name('input.search-global-typeahead__input.always-show-placeholder')

# %%
search_job.send_keys('Data analyst')

# %%
search_job.send_keys(Keys.ENTER)

# %% [markdown]
# #### Pinchar en empleo:

# %%
b_jobs = driver.find_elements_by_tag_name('button')

# %%
for i in b_jobs:
    if i.text == 'Empleos':
        button = i

# %%
button.click()

# %% [markdown]
# ### Recoger info puesto trabajo:

# %%
# Creo lista con todos la información recopilada de la empresa, por orden.

def info_collect(driver):

    info_df = []
    
    title = driver.find_elements_by_tag_name('div.jobs-details-top-card__content-container')
   
    title = title[0].text.splitlines()
    
    
    if len(title) < 9:

        title = [title [0], '', '', '', '']

    elif title[5] == 'Nuevo':
        title = [title[2], title[0], title[4], title[7], title[9]]

    else:
        title = [title[2], title[0], title[4], title[6], title[8]]
        
        
    
    info_job_comp = driver.find_elements_by_tag_name('li.artdeco-list__item.jobs-details-job-summary-list__item.jobs-details-job-summary-list__item--bullet')
    
    info_job_comp = info_job_comp[0].text.splitlines()
    
    
    job_desc = driver.find_elements_by_tag_name('div.jobs-box__html-content.jobs-description-content__text.t-14.t-normal')
    
    job_desc1 = [job_desc[0].text]
    

    
    job_desc2 = job_desc[0].text.splitlines()[-8:]
    
    job_desc2 = [job_desc2[1], job_desc2[3], job_desc2[5], job_desc2[7]]
    
    info_df = title + job_desc2 + job_desc1
    
    return info_df

# %% [markdown]
# ### Recolección Data Analysis

# %%
# Creo los títulos de las columnas del df.

titulos_col = ['Nombre empresa', 'Puesto ofertado', 'Ubicación', 'Días activos', 'Nº Solicitudes', 'Nivel experiencia', 'Sector', 'Tipo jornada', 'Funciones laborales', 'Descripción']

jobs_list = pd.DataFrame()

# %%
parentElement = driver.find_element_by_class_name("jobs-search-results__list.list-style-none")
elementList = parentElement.find_elements_by_class_name("mr1.artdeco-entity-lockup__image.artdeco-entity-lockup__image--type-square.ember-view")

# %%
for i in range(len(elementList)):
    elementList[i].click()
    time.sleep(2)
    info_df = info_collect(driver)
    df_prueba = pd.DataFrame([info_df], columns = titulos_col)
    jobs_list = jobs_list.append(df_prueba)

# %%
jobs_list
# Out:
#                       Nombre empresa  \
# 0                              Auth0
# 0                              Talan
# 0                          Grupo BME
# 0                              Agoda
# 0                     Too Good To Go
# 0                               eBay
# 0                             Amazon
# 0                          mAbxience
# 0       Hyundai Motor España, S.L.U.
# 0                    Deloitte España
# 0                    Garaje de Ideas
# 0                          Lingokids
# 0                          SEAT:CODE
# 0                           Designit
# 0                             Cabify
# 0                      UPartnerMedia
# 0                          Cognizant
# 0  UNIR - La Universidad en Internet
# 0                   Deporvillage.com
# 0                               XING
# 0                       Jobandtalent
# 0             Savills Aguirre Newman
# 0                             Dentsu
# 0                  Strategy Big Data
# 0                        Trina Solar
#
#                                      Puesto ofertado  \
# 0                              Business Data Analyst
# 0                                       Data Analyst
# 0                                       Data Analyst
# 0  Data Analyst (Bangkok Based, relocation provided)
# 0                                       Data Analyst
# 0                                       Data Analyst
# 0                                Junior Data Analyst
# 0                            Junior CMC Data Analyst
# 0                           Data Analyst - Logistics
# 0                                       Data Analyst
# 0                                       Data Analyst
# 0                                       Data Analyst
# 0                         DATA Analyst (full remote)
# 0                              Data Analyst (Remote)
# 0                                       Data Analyst
# 0                                 Media Data Analyst
# 0                            Junior Big Data Analyst
# 0                                    HR Data Analyst
# 0                                       Data Analyst
# 0                            Junior Big Data Analyst
# 0                               Product Data Analyst
# 0                                       Data Analyst
# 0                  Data & Analytics Strategy Analyst
# 0                                       Data Analyst
# 0                                 Solar Data Analyst
#
#                                            Ubicación  \
# 0                Madrid, Comunidad de Madrid, España
# 0                               Madrid y alrededores
# 0                               Madrid y alrededores
# 0                Madrid, Comunidad de Madrid, España
# 0                Madrid, Comunidad de Madrid, España
# 0                Madrid, Comunidad de Madrid, España
# 0                        Barcelona, Cataluña, España
# 0                Madrid, Comunidad de Madrid, España
# 0                Madrid, Comunidad de Madrid, España
# 0                Madrid, Comunidad de Madrid, España
# 0                Madrid, Comunidad de Madrid, España
# 0                Madrid, Comunidad de Madrid, España
# 0                        Barcelona, Cataluña, España
# 0      Madrid, Comunidad de Madrid, España En remoto
# 0                Madrid, Comunidad de Madrid, España
# 0                Madrid, Comunidad de Madrid, España
# 0                Madrid, Comunidad de Madrid, España
# 0                Madrid, Comunidad de Madrid, España
# 0                            Barcelona y alrededores
# 0  Catarroja, Comunidad Valenciana / Comunitat Va...
# 0                Madrid, Comunidad de Madrid, España
# 0                Madrid, Comunidad de Madrid, España
# 0                Madrid, Comunidad de Madrid, España
# 0                                   España En remoto
# 0                Madrid, Comunidad de Madrid, España
#
#                     Días activos        Nº Solicitudes  \
# 0     Publicado hace hace 5 días   144 visualizaciones
# 0     Publicado hace hace 6 días   342 visualizaciones
# 0  Publicado hace hace 3 semanas  2969 visualizaciones
# 0  Publicado hace hace 3 semanas   133 visualizaciones
# 0    Publicado hace hace 4 horas   256 visualizaciones
# 0      Publicado hace hace 1 día     9 visualizaciones
# 0   Publicado hace hace 1 semana  4366 visualizaciones
# 0      Publicado hace hace 1 día   832 visualizaciones
# 0   Publicado hace hace 15 horas   990 visualizaciones
# 0    Publicado hace hace 3 meses  3517 visualizaciones
# 0     Publicado hace hace 5 días   528 visualizaciones
# 0      Publicado hace hace 1 mes    73 visualizaciones
# 0  Publicado hace hace 3 semanas   566 visualizaciones
# 0     Publicado hace hace 6 días   759 visualizaciones
# 0  Publicado hace hace 3 semanas   291 visualizaciones
# 0     Publicado hace hace 3 días   711 visualizaciones
# 0      Publicado hace hace 1 mes   258 visualizaciones
# 0  Publicado hace hace 3 semanas   462 visualizaciones
# 0      Publicado hace hace 1 día   647 visualizaciones
# 0   Publicado hace hace 1 semana   452 visualizaciones
# 0  Publicado hace hace 2 semanas   343 visualizaciones
# 0  Publicado hace hace 3 semanas   333 visualizaciones
# 0     Publicado hace hace 6 días   319 visualizaciones
# 0   Publicado hace hace 1 semana   512 visualizaciones
# 0  Publicado hace hace 3 semanas   451 visualizaciones
#
#             Nivel experiencia  \
# 0                  Intermedio
# 0                  Intermedio
# 0     Algo de responsabilidad
# 0     Algo de responsabilidad
# 0             Sin experiencia
# 0             Sin experiencia
# 0             Sin experiencia
# 0     Algo de responsabilidad
# 0     Algo de responsabilidad
# 0             Sin experiencia
# 0
# 0             Sin experiencia
# 0     Algo de responsabilidad
# 0             Sin experiencia
# 0             Sin experiencia
# 0       Modelos econométricos
# 0             Sin experiencia
# 0                  Intermedio
# 0                  Intermedio
# 0  Relocation pack if needed.
# 0     Algo de responsabilidad
# 0     Algo de responsabilidad
# 0     Algo de responsabilidad
# 0             Sin experiencia
# 0                  Intermedio
#
#                                               Sector  \
# 0  Software Seguridad del ordenador y de las rede...
# 0                            Servicio de información
# 0                                Mercados de capital
# 0                                           Internet
# 0  Marketing y publicidad Alimentación y bebidas ...
# 0  Marketing y publicidad Servicios y tecnologías...
# 0  Software Servicios y tecnologías de la informa...
# 0                             Industria farmacéutica
# 0                             Sector automovilístico
# 0  Servicios y tecnologías de la información Soft...
# 0  Si te suena bien, haz click en “solicitar”, ¡e...
# 0                                         E-learning
# 0                         Desarrollo de programación
# 0             Marketing y publicidad Diseño Software
# 0   Marketing y publicidad Internet Recursos humanos
# 0
# 0  Servicios y tecnologías de la información Dota...
# 0  Servicios y tecnologías de la información Gest...
# 0                      Internet Artículos deportivos
# 0  Check our Twitter account! https://twitter.com...
# 0                                           Internet
# 0                               Bienes inmobiliarios
# 0                             Marketing y publicidad
# 0          Servicios y tecnologías de la información
# 0  Energía renovable y medio ambiente Petróleo y ...
#
#                                         Tipo jornada  \
# 0                                   Jornada completa
# 0                                   Jornada completa
# 0                                   Jornada completa
# 0                                   Jornada completa
# 0                                   Jornada completa
# 0                                   Jornada completa
# 0                                   Jornada completa
# 0                                   Jornada completa
# 0                                   Jornada completa
# 0                                   Jornada completa
# 0  Si tu perfil encaja con lo que estamos buscand...
# 0                                   Jornada completa
# 0                                   Jornada completa
# 0                                  Contrato por obra
# 0                                   Jornada completa
# 0  Fecha de incorporación: Inmediata- Contrato In...
# 0                                   Jornada completa
# 0                                   Jornada completa
# 0                                   Jornada completa
# 0  We contribute into open source https://github....
# 0                                   Jornada completa
# 0                                   Jornada completa
# 0                                   Jornada completa
# 0                                   Jornada completa
# 0                                   Jornada completa
#
#                                  Funciones laborales  \
# 0                       Tecnología de la información
# 0  Tecnología de la información Consultoría Gesti...
# 0                       Tecnología de la información
# 0                       Tecnología de la información
# 0                       Tecnología de la información
# 0                       Tecnología de la información
# 0  Estrategia/planificación Análisis Tecnología d...
# 0        Gestión de proyectos Investigación Ciencias
# 0     Negocios Tecnología de la información Análisis
# 0                       Tecnología de la información
# 0                                   Jornada completa
# 0                       Tecnología de la información
# 0                       Tecnología de la información
# 0                       Tecnología de la información
# 0                       Tecnología de la información
# 0                                   Jornada completa
# 0                                               Otro
# 0                                   Recursos humanos
# 0  Ingeniería Tecnología de la información Desarr...
# 0                                   Jornada completa
# 0                       Tecnología de la información
# 0                                               Otro
# 0            Ingeniería Tecnología de la información
# 0                       Tecnología de la información
# 0                               Gestión de proyectos
#
#                                          Descripción
# 0  Auth0 is a unicorn that just closed a $120M Se...
# 0  Anunciado por\nPaula Vázquez González\nHR Gene...
# 0  Anunciado por\nGermán López Arranz\nTalent Acq...
# 0  About Agoda\n\nAgoda is an online travel booki...
# 0  1/3 of the food produced in the world is waste...
# 0  The opportunity\n\nWe are looking for an exper...
# 0  Description\n\nJunior Data Analyst\nWe are hir...
# 0  General Responsibility\nSupport CMC Specialist...
# 0  Principales Funciones y Responsabilidades\n\nD...
# 0  Deloitte Tecnología esta buscandoprofesionales...
# 0  Lo que buscamos es…\nUna persona con 3 o 4 año...
# 0  Lingokids mission is to help 100 million famil...
# 0  At the SEAT:CODE we are constantly looking for...
# 0  Are you ready to support digital programmes wi...
# 0  Do you want to help us to change the world? We...
# 0  UPartner incorpora a su equipo un MEDIA ANALYS...
# 0  Graduate Analyst - Junior BIG DATA Analyst\n\n...
# 0  Anunciado por\nMaría Sonsoles Zazo Pindado\nPs...
# 0  Deporvillage is one of the biggest european e-...
# 0  XING is the social network for business profes...
# 0  Who we are: We are a workforce on-demand compa...
# 0  En Savills Aguirre Newman, consultora inmobili...
# 0  Responsabilidades:\nImplementación y supervisi...
# 0  Anunciado por\nKarla Maryed Blanco Rodriguez\n...
# 0  Anunciado por\nRuben Hernandez\nHR Manager Eur...

# %%
jobs_list.to_csv('info_data_analysis.csv')

# %% [markdown]
# ### Recolección Data Scientist

# %%
parentElement = driver.find_element_by_class_name("jobs-search-results__list.list-style-none")
elementList = parentElement.find_elements_by_class_name("mr1.artdeco-entity-lockup__image.artdeco-entity-lockup__image--type-square.ember-view")

# %%
# Creo los títulos de las columnas del df.

titulos_col = ['Nombre empresa', 'Puesto ofertado', 'Ubicación', 'Días activos', 'Nº Solicitudes', 'Nivel experiencia', 'Sector', 'Tipo jornada', 'Funciones laborales', 'Descripción']

# %%
jobs_data_scientist_list = pd.DataFrame()

# %%
for i in range(len(elementList)):
    elementList[i].click()
    time.sleep(2)
    info_df = info_collect(driver)
    df_prueba = pd.DataFrame([info_df], columns = titulos_col)
    jobs_data_scientist_list = jobs_data_scientist_list.append(df_prueba)

# %%
jobs_data_scientist_list
# Out:
#                                Nombre empresa  \
# 0                                      Amazon
# 0                Zurich Insurance Company Ltd
# 0                             El Corte Inglés
# 0                                       WIRIS
# 0                                       MANGO
# ..                                        ...
# 0   Eurecat - Centro Tecnológico de Catalunya
# 0             Barcelona Supercomputing Center
# 0                                      Amazon
# 0        Universitat Pompeu Fabra - Barcelona
# 0                               Grupo Digital
#
#                                       Puesto ofertado  \
# 0                                      Data Scientist
# 0                                      Data Scientist
# 0                                       Data Engineer
# 0                                       Data Engineer
# 0                                      Data Scientist
# ..                                                ...
# 0   ROBOTICS RESEARCHER (COMPUTER VISION AND DEEP ...
# 0                  Quantum algorithms researcher (R3)
# 0                                      Data Scientist
# 0                 MetaWireless Early-Stage Researcher
# 0       Data Engineer // Data Integration POWERCENTER
#
#                                      Ubicación                  Días activos  \
# 0                  Barcelona, Cataluña, España    Publicado hace hace 2 días
# 0                  Barcelona, Cataluña, España  Publicado hace hace 11 horas
# 0          Madrid, Comunidad de Madrid, España  Publicado hace hace 1 semana
# 0                      Barcelona y alrededores  Publicado hace hace 1 semana
# 0   Palau-solità i Plegamans, Cataluña, España   Publicado hace hace 7 horas
# ..                                         ...                           ...
# 0      Cerdanyola del Vallès, Cataluña, España  Publicado hace hace 15 horas
# 0                  Barcelona, Cataluña, España  Publicado hace hace 1 semana
# 0                  Barcelona, Cataluña, España     Publicado hace hace 1 día
# 0                  Barcelona, Cataluña, España     Publicado hace hace 1 mes
# 0                  Barcelona, Cataluña, España    Publicado hace hace 3 días
#
#           Nº Solicitudes        Nivel experiencia  \
# 0    749 visualizaciones         Job ID: A1469178
# 0    180 visualizaciones               Intermedio
# 0   2011 visualizaciones  Algo de responsabilidad
# 0    305 visualizaciones  Algo de responsabilidad
# 0    215 visualizaciones  Algo de responsabilidad
# ..                   ...                      ...
# 0     24 visualizaciones          Sin experiencia
# 0     53 visualizaciones  Algo de responsabilidad
# 0     90 visualizaciones          Sin experiencia
# 0     12 visualizaciones  Algo de responsabilidad
# 0     23 visualizaciones          Sin experiencia
#
#                                                Sector       Tipo jornada  \
# 0   Software Servicios y tecnologías de la informa...   Jornada completa
# 0                       Seguros Servicios financieros   Jornada completa
# 0   Venta al por menor Artículos de consumo Servic...   Jornada completa
# 0                                            Software   Jornada completa
# 0                                  Venta al por menor   Jornada completa
# ..                                                ...                ...
# 0   Servicios y tecnologías de la información Soft...  Contrato por obra
# 0   Servicios y tecnologías de la información Soft...   Jornada completa
# 0   Servicios y tecnologías de la información Soft...   Jornada completa
# 0           Enseñanza superior Software Investigación   Jornada completa
# 0                                            Internet   Jornada completa
#
#                                   Funciones laborales  \
# 0             Ingeniería Tecnología de la información
# 0                            Estrategia/planificación
# 0   Consultoría Ingeniería Tecnología de la inform...
# 0                        Tecnología de la información
# 0      Análisis Negocios Tecnología de la información
# ..                                                ...
# 0                                                Otro
# 0   Investigación Análisis Tecnología de la inform...
# 0             Ingeniería Tecnología de la información
# 0   Investigación Análisis Tecnología de la inform...
# 0                        Tecnología de la información
#
#                                           Descripción
# 0   Description\n\nWe are looking for a Data Scien...
# 0   The purpose of Zurich is...\n\nWhat are we loo...
# 0   Si lo que buscas es una empresa innovadora y l...
# 0   Anunciado por\nJulia Abad Castelló\nTalent Acq...
# 0   Buscamos un/a Data Scientist para que se incor...
# ..                                                ...
# 0   Eurecat Centro Tecnológico de Cataluña\n\nCATA...
# 0   Offer Description\n\nContext and Mission\n\nTh...
# 0   We are looking for a Data Scientist to help Am...
# 0   The Wireless & Secure Communications (WiSeCom)...
# 0   Seleccionamos para importante compañia del sec...
#
# [515 rows x 10 columns]

# %%
jobs_data_scientist_list.to_csv('info_data_scientist.csv')
